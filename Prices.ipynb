# %%
import sqlalchemy
import pandas as pd

engine = sqlalchemy.create_engine('sqlite://prices.db')

df = pd.read_sql('settle_prices', engine)

#Returning all rows in dataframe where column value "type" equals 5

df[df.type==5]

pd.read_csv('tickers.csv', sep='|')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\DYLANH~1\AppData\Local\Temp/ipykernel_18092/3504515472.py in <module>
# ----> 1 import sqlalchemy
#       2 import pandas as pd
#       3
#       4 engine = sqlalchemy.create_engine('sqlite://prices.db')
#       5
#
# ModuleNotFoundError: No module named 'sqlalchemy'
